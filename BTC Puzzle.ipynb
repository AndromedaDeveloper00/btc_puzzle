# %%
# !git clone https://github.com/AndromedaDeveloper00/btc_puzzle.git
# Out:
# Cloning into 'btc_puzzle'...
# Username for 'https://github.com': ^C

# %%
cd ./btc_puzzle
# Out:
# '/kaggle/working'

# %%
./cuBitcrack --list-devices
